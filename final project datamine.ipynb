# %%
import pandas as pd
import numpy as np

# %%
auto = 'autos.csv'
autodf = pd.read_csv(auto)

# %%
autodf
# Out:
#                 dateCrawled  \
# 0       2016-03-24 11:52:17
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 7       2016-03-21 18:54:38
# 8       2016-04-04 23:42:13
# 9       2016-03-17 10:53:50
# 10      2016-03-26 19:54:18
# 11      2016-04-07 10:06:22
# 12      2016-03-15 22:49:09
# 13      2016-03-21 21:37:40
# 14      2016-03-21 12:57:01
# 15      2016-03-11 21:39:15
# 16      2016-04-01 12:46:46
# 17      2016-03-20 10:25:19
# 18      2016-03-23 15:48:05
# 19      2016-04-01 22:55:47
# 20      2016-04-01 19:56:48
# 21      2016-03-27 11:38:00
# 22      2016-03-23 14:52:51
# 23      2016-03-12 19:43:07
# 24      2016-03-13 20:40:49
# 25      2016-03-18 21:44:09
# 26      2016-03-10 19:38:18
# 27      2016-03-07 12:51:23
# 28      2016-03-09 11:56:38
# 29      2016-03-08 19:55:19
# ...                     ...
# 371498  2016-03-11 15:50:38
# ...

# %%
print autodf["vehicleType"].unique()
print autodf["name"].unique()
print autodf["gearbox"].unique()
# Out:
# [nan 'coupe' 'suv' 'kleinwagen' 'limousine' 'cabrio' 'bus' 'kombi'
#  'andere']
# ['Golf_3_1.6' 'A5_Sportback_2.7_Tdi' 'Jeep_Grand_Cherokee_"Overland"' ...
#  'Smart_smart_leistungssteigerung_100ps' 'VW_Golf_Kombi_1_9l_TDI'
#  'BMW_M135i_vollausgestattet_NP_52.720____Euro']
# ['manuell' 'automatik' nan]

# %%
import apyori

# %%
g = apyori.apriori(autodf.as_matrix())

# %%
l = list(g)

# %%
l
# Out:
# [RelationRecord(items=frozenset([nan]), support=0.29761417712796884, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset([nan]), confidence=0.29761417712796884, lift=1.0)]),
#  RelationRecord(items=frozenset([0]), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset([0]), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset([125000]), support=0.10246872375702504, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset([125000]), confidence=0.10246872375702504, lift=1.0)]),
#  RelationRecord(items=frozenset([150000]), support=0.6481368833573782, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset([150000]), confidence=0.6481368833573782, lift=1.0)]),
# ...

# %%
import cPickle as pickle

# %%
with open("apriori-result", "wb") as f:
    pickle.dump(l, f)

# %%
with open("apriori-result", "rb") as f:
    q = pickle.load(f)
    print q
# Out:
# [RelationRecord(items=frozenset([nan]), support=0.29761417712796884, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset([nan]), confidence=0.29761417712796884, lift=1.0)]), RelationRecord(items=frozenset([0]), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset([0]), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset([125000]), support=0.10246872375702504, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset([125000]), confidence=0.10246872375702504, lift=1.0)]), RelationRecord(items=frozenset([150000]), support=0.6481368833573782, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset([150000]), confidence=0.6481368833573782, lift=1.0)]), RelationRecord(items=frozenset(['Angebot']), support=0.9999677009538985, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset(['Angebot']), confidence=0.9999677009538985, lift=1
# ...

# %%
q[0]
# Out:
# RelationRecord(items=frozenset([nan]), support=0.29761417712796884, ordered_statistics=[OrderedStatistic(items_base=frozenset([]), items_add=frozenset([nan]), confidence=0.29761417712796884, lift=1.0)])

# %%
[i for i in q if i.lift>1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-495d08a2d077> in <module>()
# ----> 1 [i for i in q if i.lift>1]
#
# AttributeError: 'RelationRecord' object has no attribute 'lift'

# %%
q[19].ordered_statistics
# Out:
# [OrderedStatistic(items_base=frozenset([nan]), items_add=frozenset([0]), confidence=1.0, lift=1.0),
#  OrderedStatistic(items_base=frozenset([0]), items_add=frozenset([nan]), confidence=0.29761417712796884, lift=1.0)]

# %%
q[19]
# Out:
# RelationRecord(items=frozenset([nan, 0]), support=0.29761417712796884, ordered_statistics=[OrderedStatistic(items_base=frozenset([nan]), items_add=frozenset([0]), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset([0]), items_add=frozenset([nan]), confidence=0.29761417712796884, lift=1.0)])
